# %%
import pandas as pd

# %%
data = pd.read_excel("./data/meadjohnson.xlsx")

# %%
data
# Out:
#               Unnamed: 0 Unnamed: 1   Unnamed: 2  \
# 0                   开始时间       通话时长         来电号码
# 1    2020-12-13 22:35:34   00:00:59  18646043825
# 2    2020-12-13 16:28:13   00:01:31  18975800902
# 3    2020-12-13 18:16:50   00:00:19  18227429081
# 4    2020-12-13 18:25:13   00:01:15  15167183809
# ..                   ...        ...          ...
# 96   2020-12-13 21:15:37   00:00:35  15128205930
# 97   2020-12-13 20:37:37   00:01:18  18230788070
# 98   2020-12-13 08:58:57   00:01:21  13069482488
# 99   2020-12-13 17:31:09   00:00:33  13275700531
# 100  2020-12-13 17:39:04   00:04:36  13680771886
#
#                                             Unnamed: 3      Unnamed: 4  \
# 0                                 对话(错误数据：范围内标红，范围外标黄)  Comment Number
# 1    A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:查询证件...               5
# 2    A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入...               3
# 3             A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\n               0
# ...

# %%
data.columns = data.iloc[0]
data = data[1:]
# Out:
# 0                   开始时间      通话时长         来电号码  \
# 1    2020-12-13 22:35:34  00:00:59  18646043825
# 2    2020-12-13 16:28:13  00:01:31  18975800902
# 3    2020-12-13 18:16:50  00:00:19  18227429081
# 4    2020-12-13 18:25:13  00:01:15  15167183809
# 5    2020-12-13 17:14:10  00:01:50  18817594831
# ..                   ...       ...          ...
# 96   2020-12-13 21:15:37  00:00:35  15128205930
# 97   2020-12-13 20:37:37  00:01:18  18230788070
# 98   2020-12-13 08:58:57  00:01:21  13069482488
# 99   2020-12-13 17:31:09  00:00:33  13275700531
# 100  2020-12-13 17:39:04  00:04:36  13680771886
#
# 0                                 对话(错误数据：范围内标红，范围外标黄) Comment Number  \
# 1    A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:查询证件...              5
# 2    A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入...              3
# 3             A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\n              0
# 4    A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:证件审核...              7
# ...

# %%
data
# Out:
# 0                   开始时间      通话时长         来电号码  \
# 1    2020-12-13 22:35:34  00:00:59  18646043825
# 2    2020-12-13 16:28:13  00:01:31  18975800902
# 3    2020-12-13 18:16:50  00:00:19  18227429081
# 4    2020-12-13 18:25:13  00:01:15  15167183809
# 5    2020-12-13 17:14:10  00:01:50  18817594831
# ..                   ...       ...          ...
# 96   2020-12-13 21:15:37  00:00:35  15128205930
# 97   2020-12-13 20:37:37  00:01:18  18230788070
# 98   2020-12-13 08:58:57  00:01:21  13069482488
# 99   2020-12-13 17:31:09  00:00:33  13275700531
# 100  2020-12-13 17:39:04  00:04:36  13680771886
#
# 0                                 对话(错误数据：范围内标红，范围外标黄) Comment Number  \
# 1    A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:查询证件...              5
# 2    A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入...              3
# 3             A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\n              0
# 4    A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:证件审核...              7
# ...

# %%
qa_data = data.iloc[:, 3]
qa_data
# Out:
# 1      A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:查询证件...
# 2      A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入...
# 3               A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\n
# 4      A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:证件审核...
# 5      A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:奶粉泡出...
#                              ...
# 96     A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:帮我开通...
# 97     A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:我问一下...
# 98     A:让我帮您查一下礼品的物流情况，请用电话键盘输入您咨询的活动。蓝臻积分臻赏荟请按1，解码有...
# 99     A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入...
# 100    A:让我帮您查一下礼品的物流情况，请用电话键盘输入您咨询的活动。蓝臻积分臻赏荟请按1，解码有...
# Name: 对话(错误数据：范围内标红，范围外标黄), Length: 100, dtype: object

# %%
text_data = []

# %%
# qa_data.iloc[0]
for qa in qa_data:
    print(qa)
# Out:
# A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]
# B:查询证件审核情况。 [voice]
# A:让我帮您查一下您的证件审核情况，请用电话键盘输入您咨询的活动。蓝臻积分臻赏荟请按1.解码有礼请按2其他活动请按3，退出键盘输入请按9。 [keyboard]
# B:1 [voice]
# A:您的来电号码是您的会员注册号码吗？ [voice]
# B:50 [voice]
# A:您的来电号码是您的会员注册号码吗？ [voice]
# B:不是。 [voice]
# A:请用电话键盘输入您的会员注册号码，或者按9退出键盘输入，并按井号键结束。 [keyboard]
# B:15837276437 [voice]
# A:您好，后台查询到您的证件审核已通过。，请问还有什么可以帮您？ [voice]
#
# A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入，并按井号键结束。 [voice]
# B:8712045030608 [voice]
# A:您输入的防伪码格式不正确，正确的格式为防伪码下方的16位数字，请重新输入防伪码，或者按9退出键盘输入，按井号键结束。 [keyboard]
# B:  [voice]
# A:您输入的防伪码格式不正确，正确的格式为防伪码下方的16位数字，请重新输入防伪码，或者按9退出键盘输入，按井号键结束。 [keyboard]
# B:9 [voice]
# A:请问还有什么可以帮您？ [voice]
#
# A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]
#
# A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]
# B:证件审核情况。 [voice]
# A:让我帮您查一下您的证件审核情况，请用电话键盘输入您咨询的活动。蓝臻积分臻赏荟请按1.解码有礼请按2其他活动请按3，退出键盘输入请按9。 [keyboard]
# B:1 [voice]
# A:您的来电号码是您的会员注册号码吗？ [voice]
# B:对面都是。 [voice]
# A:您好，后台查询到该会员号码还没有上传证件哦，麻烦上传证件，谢谢。，请问还有什么可以帮您？ [voice]
# B:证件审核节目。 [voice]
# ...

# %%
text_data = []
for qa in qa_data:
    text_data.append(qa)

# %%
text_data
# Out:
# ['A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\nB:查询证件审核情况。 [voice]\nA:让我帮您查一下您的证件审核情况，请用电话键盘输入您咨询的活动。蓝臻积分臻赏荟请按1.解码有礼请按2其他活动请按3，退出键盘输入请按9。 [keyboard]\nB:1 [voice]\nA:您的来电号码是您的会员注册号码吗？ [voice]\nB:50 [voice]\nA:您的来电号码是您的会员注册号码吗？ [voice]\nB:不是。 [voice]\nA:请用电话键盘输入您的会员注册号码，或者按9退出键盘输入，并按井号键结束。 [keyboard]\nB:15837276437 [voice]\nA:您好，后台查询到您的证件审核已通过。，请问还有什么可以帮您？ [voice]\n',
#  'A:让我来帮您查一下奶粉的真假，请用电话键盘输入防伪码下方的16位数字，或者按9退出键盘输入，并按井号键结束。 [voice]\nB:8712045030608 [voice]\nA:您输入的防伪码格式不正确，正确的格式为防伪码下方的16位数字，请重新输入防伪码，或者按9退出键盘输入，按井号键结束。 [keyboard]\nB:  [voice]\nA:您输入的防伪码格式不正确，正确的格式为防伪码下方的16位数字，请重新输入防伪码，或者按9退出键盘输入，按井号键结束。 [keyboard]\nB:9 [voice]\nA:请问还有什么可以帮您？ [voice]\n',
#  'A:您好，我是美赞臣热线智能客服机器人，请问有什么可以帮您？ [voice]\n',
# ...

# %%
with open("./data/meadjohnson.txt", 'w') as f:
    for qa in text_data:
        f.write(qa)
        f.write("\n")
